# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#sklearn library used to split train and test model
from sklearn.model_selection import train_test_split
#Then call train_test_split function it is parameterised function
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={"kernel":['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
#fitting the model for grid search
grid.fit(X_train,Y_train)
#regressor=SVR(kernel="precomputed",C=10)
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\prave\Anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.2s finished
# C:\Users\prave\Anaconda3\envs\aiml\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='auto_deprecated', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print (re)
grid_predictions=grid.predict(X_test)
#print classification report
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter{'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}: 0.8598930084494388

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0
# 12           0.158637           0.155756         0.198441        0.058341
# 13           0.450772           0.421861         0.462532        0.038908
# 14           0.426898           0.421539         0.448013        0.033721
# 15           0.573673           0.559680         0.578059        0.017081
# 16           0.671971           0.640038         0.675184        0.030094
# 17           0.795391           0.764729         0.785907        0.015002
# 18           0.336416           0.349444         0.363694        0.029842
# 19           0.673763           0.637674         0.658471        0.015239
# 20           0.671576           0.639937         0.675112        0.030267
# 21           0.795738           0.764963         0.785952        0.014853
# 22           0.319360           0.346897         0.350668        0.027233
# 23           0.673763           0.637674         0.658471        0.015239
# 24           0.780655           0.746425         0.773770        0.020115
# 25           0.813670           0.779845         0.805377        0.018419
# 26          -0.162949          -0.041406        -0.132252        0.065354
# 27           0.621857           0.634263         0.655411        0.039010
# 28           0.780342           0.746377         0.773721        0.020174
# 29           0.813718           0.779857         0.805144        0.018187
# 30          -0.046722          -0.043343        -0.042940        0.003266
# 31           0.621857           0.634263         0.655411        0.039010
# 32           0.800880           0.768195         0.791578        0.016649
# 33           0.814057           0.783380         0.807463        0.017600
# 34          -0.652358          -0.912173        -0.833192        0.128209
# 35           0.621851           0.632748         0.654873        0.039248
# 36           0.800723           0.768175         0.791584        0.016684
# 37           0.813966           0.783395         0.807463        0.017607
# 38          -1.126127          -0.940265        -0.997079        0.091467
# 39           0.621851           0.632748         0.654873        0.039248
#
#     rank_test_score
# 0                36
# 1                32
# 2                34
# 3                27
# 4                37
# 5                31
# 6                33
# 7                27
# 8                29
# 9                22
# 10               24
# 11               19
# 12               30
# 13               21
# 14               23
# 15               19
# 16               11
# 17                8
# 18               25
# 19               13
# 20               12
# 21                7
# 22               26
# 23               13
# 24                9
# 25                3
# 26               38
# 27               15
# 28               10
# 29                4
# 30               35
# 31               15
# 32                6
# 33                1
# 34               39
# 35               17
# 36                5
# 37                2
# 38               40
# 39               17

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.043243      0.001156         0.010937        0.006678      10
# 1        0.036635      0.002482         0.011045        0.004864      10
# 2        0.043454      0.002433         0.019891        0.006493      10
# 3        0.022219      0.006356         0.015636        0.005383      10
# 4        0.038196      0.006751         0.019335        0.005760      10
# 5        0.028367      0.005920         0.001223        0.001730      10
# 6        0.039271      0.004936         0.014005        0.005499      10
# 7        0.030387      0.002504         0.002421        0.003423      10
# 8        0.028348      0.006830         0.018519        0.009619     100
# 9        0.030469      0.009126         0.010043        0.008887     100
# 10       0.042403      0.002732         0.014958        0.004082     100
# 11       0.038834      0.001985         0.008853        0.006549     100
# 12       0.031462      0.006741         0.020464        0.003877     100
# 13       0.036803      0.005649         0.011147        0.008280     100
# 14       0.050451      0.003479         0.009303        0.007591     100
# 15       0.036644      0.004302         0.002835        0.002099     100
# 16       0.057410      0.005522         0.008717        0.005999    1000
# 17       0.052214      0.003134         0.007237        0.006435    1000
# 18       0.048060      0.003300         0.012916        0.002179    1000
# 19       0.047357      0.006547         0.006980        0.006491    1000
# 20       0.053200      0.007284         0.010415        0.007364    1000
# 21       0.075497      0.033541         0.008640        0.006485    1000
# 22       0.058472      0.001136         0.012085        0.004444    1000
# 23       0.053424      0.004548         0.005207        0.007364    1000
# 24       0.057694      0.000666         0.006423        0.004138    2000
# 25       0.084106      0.013794         0.003185        0.003821    2000
# 26       0.043722      0.000593         0.015335        0.000414    2000
# 27       0.063077      0.008497         0.009166        0.009308    2000
# 28       0.059285      0.000935         0.005223        0.007386    2000
# 29       0.101027      0.010783         0.006683        0.006830    2000
# 30       0.043451      0.005662         0.012604        0.003815    2000
# 31       0.059547      0.004445         0.003434        0.004856    2000
# 32       0.070814      0.008276         0.008902        0.006906    3000
# 33       0.142151      0.025173         0.016620        0.001408    3000
# 34       0.033544      0.003338         0.020463        0.006161    3000
# 35       0.095812      0.028094         0.002939        0.003474    3000
# 36       0.069387      0.006709         0.010777        0.007633    3000
# 37       0.121984      0.006568         0.001902        0.002690    3000
# 38       0.033700      0.016252         0.010819        0.007667    3000
# 39       0.085062      0.018991         0.002572        0.003637    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.001622
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.045578
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.043747
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.379453
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.001551
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.044344
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043460
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.379453
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.280420
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.519516
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.497513
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.600824
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.280931
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.514963
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.495602
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.600824
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.713543
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.797601
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.405221
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.663978
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.713824
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.797154
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.385746
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.663978
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.794232
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822616
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.192402
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.710113
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.794443
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.821856
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.038754
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.710113
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.805659
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.824951
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.935044
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.710020
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.805853
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.825027
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.924846
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.710020
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.097907          -0.088465        -0.062665        0.043335
# 1           -0.050102          -0.039371        -0.014632        0.042800
# 2           -0.054054          -0.044185        -0.018164        0.043962
# 3            0.263743           0.270498         0.304565        0.053026
# 4           -0.097995          -0.088478        -0.062675        0.043395
# 5           -0.048766          -0.039184        -0.014535        0.041817
# 6           -0.053762          -0.044135        -0.018146        0.043738
# 7            0.263743           0.270498         0.304565        0.053026
# 8            0.159180           0.155842         0.198481        0.057956
# 9            0.445794           0.421048         0.462119        0.041824
# 10           0.425077           0.420930         0.447840        0.035165
# 11           0.573673           0.559680         0.578059        0.017081
# 12           0.158637           0.155756         0.198441        0.058341
# 13           0.450772           0.421861         0.462532        0.038908
# 14           0.426898           0.421539         0.448013        0.033721
# 15           0.573673           0.559680         0.578059        0.017081
# 16           0.671971           0.640038         0.675184        0.030094
# 17           0.795391           0.764729         0.785907        0.015002
# 18           0.336416           0.349444         0.363694        0.029842
# 19           0.673763           0.637674         0.658471        0.015239
# 20           0.671576           0.639937         0.675112        0.030267
# 21           0.795738           0.764963         0.785952        0.014853
# 22           0.319360           0.346897         0.350668        0.027233
# 23           0.673763           0.637674         0.658471        0.015239
# 24           0.780655           0.746425         0.773770        0.020115
# 25           0.813670           0.779845         0.805377        0.018419
# 26          -0.162949          -0.041406        -0.132252        0.065354
# 27           0.621857           0.634263         0.655411        0.039010
# 28           0.780342           0.746377         0.773721        0.020174
# 29           0.813718           0.779857         0.805144        0.018187
# 30          -0.046722          -0.043343        -0.042940        0.003266
# 31           0.621857           0.634263         0.655411        0.039010
# 32           0.800880           0.768195         0.791578        0.016649
# 33           0.814057           0.783380         0.807463        0.017600
# 34          -0.652358          -0.912173        -0.833192        0.128209
# 35           0.621851           0.632748         0.654873        0.039248
# 36           0.800723           0.768175         0.791584        0.016684
# 37           0.813966           0.783395         0.807463        0.017607
# 38          -1.126127          -0.940265        -0.997079        0.091467
# 39           0.621851           0.632748         0.654873        0.039248
#
#     rank_test_score
# 0                36
# 1                32
# 2                34
# 3                27
# 4                37
# 5                31
# 6                33
# 7                27
# 8                29
# 9                22
# 10               24
# 11               19
# 12               30
# 13               21
# 14               23
# 15               19
# 16               11
# 17                8
# 18               25
# 19               13
# 20               12
# 21                7
# 22               26
# 23               13
# 24                9
# 25                3
# 26               38
# 27               15
# 28               10
# 29                4
# 30               35
# 31               15
# 32                6
# 33                1
# 34               39
# 35               17
# 36                5
# 37                2
# 38               40
# 39               17

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:52

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,
smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
